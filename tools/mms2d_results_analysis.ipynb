# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
results = pd.read_csv("../results/res18_unet_increasedCE/normal/results_20201207_1555.csv")
dice_cols = [col for col in results.columns if 'Dice' in col]
results.head()
# Out:
#               Name ED/ES Vendor  Centre   Dice LV  Jaccard LV  Hausdorff LV  \
# 0  A1K2P5_sa_ED_gt    ED      D       5  0.961069    0.925055     10.000000
# 1  A1K2P5_sa_ES_gt    ES      D       5  0.926197    0.862539      9.579089
# 2  A2H5K9_sa_ED_gt    ED      B       2  0.949260    0.903421      7.094594
# 3  A2H5K9_sa_ES_gt    ES      B       2  0.838323    0.721649      5.912162
# 4  A2L1N6_sa_ED_gt    ED      A       1  0.965108    0.932568      5.107864
#
#     ASSD LV  Dice MYO  Jaccard MYO  Hausdorff MYO  ASSD MYO   Dice RV  \
# 0  0.246008  0.839938     0.724045      13.824837  0.368685  0.904708
# 1  0.354296  0.912268     0.838689       5.093685  0.264318  0.829447
# 2  0.324015  0.867779     0.766439      12.261047  0.449919  0.887994
# 3  0.582341  0.857855     0.751091      38.342972  1.390848  0.850624
# 4  0.209602  0.874095     0.776348       9.703966  0.322208  0.949201
#
#    Jaccard RV  Hausdorff RV   ASSD RV
# 0    0.825997     11.137001  0.571262
# ...

# %%
print(results.groupby(['Vendor'])[dice_cols].mean())
# Out:
#          Dice LV  Dice MYO   Dice RV
# Vendor
# A       0.933387  0.831265  0.888375
# B       0.911964  0.861936  0.886019
# C       0.901706  0.828540  0.872369
# D       0.891547  0.810999  0.792819
